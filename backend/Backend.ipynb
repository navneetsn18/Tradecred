# %%
import numpy as np
import pandas as pd

# %%
filename = "test.xls"
if filename.split('.')[-1]=='xls':
    file = pd.read_excel(filename)
elif filename.split('.')[-1]=='csv':
    file = pd.read_csv(filename)

# %%
data = pd.DataFrame(file)

# %%
data
# Out:
#     Invoice Numbers  Document Number Type Net due dt  Doc. Date Pstng Date  \
# 0                 1               11   RE 2025-02-23 2017-11-23 2017-08-25
# 1                 2               22   RE 2025-02-24 2017-11-30 2017-08-25
# 2                 3               33   RE 2025-02-25 2017-11-23 2017-08-25
# 3                 4               44   RE 2025-02-26 2017-11-23 2017-08-25
# 4                 5               55   RT 2025-02-27 2017-11-23 2017-08-25
# 5                 6               66   KG 2025-02-28 2017-11-23 2017-08-25
# 6                 1               77   KD 2025-03-01 2017-11-23 2017-08-25
# 7               100               88   KD 2025-03-02 2017-11-23 2017-08-25
# 8                 7               99   KD 2025-03-03 2017-11-23 2017-08-25
# 9                 1              110   KD 2025-03-04 2017-11-23 2017-08-25
# 10                2              121   KD 2025-03-05 2017-11-23 2017-08-25
# 11              101              132   RT 2025-03-06 2017-11-23 2017-08-25
# 12              102              133   ZA 2025-03-07 2017-11-23 2017-08-25
# 13              103              134   ZA 2025-03-08 2017-11-23 2017-08-25
#
#     Amt in loc.cur. Vendor Code           Vendor name Vendor type
# 0              -100      R05001      Robert Chemicals     general
# 1              -200      R05001      Robert Chemicals     general
# 2              -300      R05001      Robert Chemicals     general
# 3              -400      R05001      Robert Chemicals     general
# 4                10      R05001      Robert Chemicals     general
# 5                30      R05001      Robert Chemicals     general
# 6                10      R05001      Robert Chemicals     general
# 7                20      R05001      Robert Chemicals     general
# 8                30      R05001      Robert Chemicals     general
# 9                40      R05001      Robert Chemicals     general
# 10               50      R05001      Robert Chemicals     general
# 11              200      R05001      Robert Chemicals     general
# 12            -2000      R05001      Robert Chemicals     general
# 13               30      C65676  Chatisgarh Chemicals     general

# %% [markdown]
# # Output
# 1. Number of invoices uploaded
# 2. Total sum of invoice amount
# 3. Total number of vendors whose invoices were uploaded
# 4. Total number of invalid invoices
